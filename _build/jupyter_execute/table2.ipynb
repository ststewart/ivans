# %% [markdown]
# # Table 2
#
# CSV format data for paper Table 2.
#
#
# <b>Summary of melt stability calculations.</b> At each pressure ($P$), we calculated the range of temperatures where CMAS melts are stable ($T_{\rm liq}$) and the wt\% of FeO in olivine (Ol) for varying atomic ratios of dust (D), tar (T), ice (I) and nebular gas (G). The atomic proportions are converted to weight percent and the total ratio of solids (D+T+I) to gas by mass ($m_{\rm s}/m_{\rm g}$).

# %%
import pandas as pd

df = pd.read_csv('table2/table2.csv')

#df.style.set_properties(**{'background-color': 'lightgray'})
#df.style.set_properties(subset=['column1', 'column2'], **{'text-align': 'center'})

#markdown_table = df.to_markdown(index=False)

# %%
display(df)
# Out:
#     P_Pa     D_at     T_at     I_at  G_at  D_wt%      T_wt%      I_wt%  \
# 0    0.4  1000000        1    50000     1   94.6   0.000050   5.400000
# 1    4.0  1000000        1    50000     1   94.6   0.000050   5.400000
# 2    4.0  1000000  1000000  1000000     1   37.5  19.700000  42.800000
# 3    4.0     1000      100      100     1   74.0   3.890000   8.450000
# 4    4.0    10000      500      500     1   90.8   2.380000   5.180000
# 5    4.0    10000      500      500     1   90.8   2.380000   5.180000
# 6    4.0    10000    10000    10000     1   37.2  19.600000  42.500000
# 7    4.0    10000    10000    10000     1   37.2  19.600000  42.500000
# 8    4.0    10000    10000    10000     1   37.2  19.600000  42.500000
# 9    4.0    10000        1        1     1   98.2   0.005160   0.011200
# 10   4.0    10000        1    10000     1   46.3   0.002430  52.800000
# 11   4.0    10000        1    10000     1   46.3   0.002430  52.800000
# ...
